# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rollback.csv')

# %%
pd.set_option('display.max_columns', 500)

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df.shape
# Out:
# (36, 24)

# %%
df
# Out:
#    starting_date        f1       auc       pr1       pr2       pr5      pr10  \
# 0       13-01-01  0.743691  0.968840  0.908137  0.797901  0.383736  0.201961
# 1       13-01-01  0.755096  0.956977  0.971067  0.828902  0.377152  0.197113
# 2       13-01-01  0.759016  0.957311  0.970344  0.814795  0.371871  0.196643
# 3       13-01-01  0.746020  0.970709  0.925497  0.799421  0.389235  0.203806
# 4       13-01-01  0.751194  0.961098  0.955877  0.804666  0.377008  0.198669
# 5       13-01-01  0.761163  0.969895  0.965642  0.822391  0.386630  0.202974
# 6       13-01-01  0.735871  0.968790  0.950814  0.800796  0.386299  0.203010
# 7       13-01-01  0.757042  0.958514  0.939241  0.803581  0.367096  0.196752
# 8       13-01-01  0.751496  0.968186  0.934901  0.799928  0.389524  0.202750
# 9       13-01-01  0.733802  0.953252  0.909584  0.775366  0.375561  0.197547
# 10      13-01-01  0.739063  0.952206  0.952984  0.782703  0.363044  0.193713
# ...

# %%
result = df.groupby(['model'])['pr1', 'pr2', 'pr5', 'pr10', 'rev1','rev2','rev5','rev10', 'auc', 'f1'].apply(lambda x: round(100 * np.mean(x), 2))
result.iloc[[1,0, 2]]
# Out:
#                                         pr1    pr2    pr5   pr10   rev1  \
# model
# DATE_13-01-01_rollback-none           94.18  81.31  38.77  20.27  44.55
# DATE_13-01-01_rollback-deterministic  92.77  77.51  37.13  19.64  44.80
# DATE_13-01-01_rollback-stochastic     95.05  78.48  36.96  19.58  42.38
#
#                                        rev2   rev5  rev10    auc     f1
# model
# DATE_13-01-01_rollback-none           66.56  83.98  89.30  96.88  75.34
# DATE_13-01-01_rollback-deterministic  63.68  77.69  84.41  95.48  72.01
# DATE_13-01-01_rollback-stochastic     63.04  77.11  83.90  95.61  73.57

# %%
result = df.groupby(['model'])['pr1', 'rev1', 'pr5', 'rev5', 'pr10','rev10'].apply(lambda x: round(100 * np.mean(x), 2))
result.iloc[[1,0, 2]]
# Out:
#                                         pr1   rev1    pr5   rev5   pr10  rev10
# model
# DATE_13-01-01_rollback-none           94.18  44.55  38.77  83.98  20.27  89.30
# DATE_13-01-01_rollback-deterministic  92.77  44.80  37.13  77.69  19.64  84.41
# DATE_13-01-01_rollback-stochastic     95.05  42.38  36.96  77.11  19.58  83.90
