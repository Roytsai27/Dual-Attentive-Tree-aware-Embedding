# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('clsrev.csv')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df.shape
# Out:
# (40, 24)

# %%
df
# Out:
#    starting_date        f1       auc       pr1       pr2       pr5      pr10  \
# 0       13-01-01  0.769648  0.968408  0.729016  0.802134  0.391911  0.203560
# 1       13-01-01  0.785867  0.968858  0.958258  0.839392  0.388945  0.202865
# 2       13-01-01  0.750667  0.966501  0.929634  0.800326  0.387788  0.202648
# 3       13-01-01  0.755261  0.955978  0.874864  0.797793  0.385907  0.200695
# 4       13-01-01  0.740265  0.967333  0.930922  0.791282  0.385617  0.201671
# 5       13-01-01  0.717645  0.965903  0.751899  0.771554  0.389090  0.204037
# 6       13-01-01  0.717830  0.968210  0.761302  0.727075  0.389596  0.202684
# 7       13-01-01  0.754360  0.966998  0.972152  0.823806  0.386196  0.201520
# 8       13-01-01  0.765212  0.966816  0.867343  0.852712  0.393575  0.202503
# 9       13-01-01  0.757940  0.970462  0.949367  0.848255  0.391172  0.203769
# 10      13-01-01  0.744658  0.966219  0.931646  0.798119  0.384098  0.200875
# ...

# %%
result = df.groupby(['model'])['pr1','re1','rev1','pr2','re2','rev2','pr5','re5','rev5','pr10','re10','rev10','auc','f1'].apply(np.mean)
result
# Out:
#                         pr1       re1      rev1       pr2       re2      rev2  \
# model
# DATE_CLS_13-01-01  0.926589  0.413291  0.449719  0.807865  0.720473  0.671422
# DATE_REV_13-01-01  0.822467  0.366285  0.492908  0.799342  0.712169  0.684768
#
#                         pr5       re5      rev5      pr10      re10     rev10  \
# model
# DATE_CLS_13-01-01  0.387707  0.864856  0.843465  0.202390  0.902929  0.890336
# DATE_REV_13-01-01  0.387361  0.864082  0.845724  0.201146  0.897410  0.892042
#
#                         auc        f1
# model
# DATE_CLS_13-01-01  0.967898  0.753207
# DATE_REV_13-01-01  0.956631  0.752344

# %%
result.index
# Out:
# Index(['DATE_CLS_13-01-01', 'DATE_REV_13-01-01'], dtype='object', name='model')

# %%
for idx in result.index:
    print(idx+' & '+'\% & '.join(list(round(result.loc[idx]*100, 2).astype(str)))+'\%')
# Out:
# DATE_CLS_13-01-01 & 92.66\% & 41.33\% & 44.97\% & 80.79\% & 72.05\% & 67.14\% & 38.77\% & 86.49\% & 84.35\% & 20.24\% & 90.29\% & 89.03\% & 96.79\% & 75.32\%
# DATE_REV_13-01-01 & 82.25\% & 36.63\% & 49.29\% & 79.93\% & 71.22\% & 68.48\% & 38.74\% & 86.41\% & 84.57\% & 20.11\% & 89.74\% & 89.2\% & 95.66\% & 75.23\%
